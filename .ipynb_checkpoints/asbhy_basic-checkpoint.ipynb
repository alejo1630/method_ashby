# %% [markdown]
# ### Importación de librerias

# %%
import pandas as pd # Manejo de bases de datos
import matplotlib.pyplot as plt #Gráficas
import numpy as np # Operaciones Matemáticas
import seaborn as sns # Gráficas pro
from sympy import init_session # Uso de Latex

# %%
init_session(use_latex=True) # Inicializar latex
# Out:
# IPython console for SymPy 1.9 (Python 3.10.2-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %% [markdown]
# ### Cargar base de datos

# %%
df = pd.read_excel("Base_de_datos_materiales.xlsx") # Esta función sirve para leer un excel
df.head()
# Out:
# C:\Users\ThinkStation\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                Nombre    Familia  Precio [USD/kg]  \
# 0                             Aerogel  Cerámicos           120.00
# 1  Manta Aislamiento Zirconia-alumina  Cerámicos           130.00
# 2                    OXIDO DE SILICIO  Cerámicos             8.00
# 3        Acetato Butirado de Celulosa  Cerámicos           164.00
# 4                           Bentonita  Cerámicos             3.12
#
#    Densidad [kg/m^3]  Modulo de Young [GPa]  Esfuerzo de Fluencia [MPa]  \
# 0               10.0                  0.001                      0.0003
# 1               96.0                205.000                    400.0000
# 2              180.0                 66.300                         NaN
# 3              800.0                 50.000                         NaN
# 4             1360.0                  2.000                      1.5600
#
#    Esfuerzo Último [MPa]  Elongación [%]  Dureza [Vickers]  \
# 0                  0.016          0.0002               1.0
# 1               1400.000             NaN             100.0
# 2                300.000             NaN            3500.0
# 3                300.000             NaN             340.0
# 4                 55.000         20.0000             250.0
#
#    Tenacidad a la fractura [MPa m^1/2]  Temperatura de fusión [K]  \
# 0                                 4.80                     773.00
# 1                                 5.60                    2281.15
# 2                                 0.67                    1988.15
# 3                                 2.50                        NaN
# 4                                 3.40                    1473.15
#
#                                   Fuente          Persona
# 0                             www.matweb           2020-2
# 1         DiaTerm. interempresas. MatWeb      Diego Rojas
# 2                                 MATWEB           2020-2
# 3                        Matweb. Precio   Nikolai Fandiño
# 4  researchgate . Matweb .  skb. marphil      Diego Rojas

# %% [markdown]
# ### Procesamiento Inicial base de datos

# %%
# Borrar columnas Fuente y Persona
df = df.drop(columns=['Fuente', 'Persona'])
df.head()
# Out:
#                                Nombre    Familia  Precio [USD/kg]  \
# 0                             Aerogel  Cerámicos           120.00
# 1  Manta Aislamiento Zirconia-alumina  Cerámicos           130.00
# 2                    OXIDO DE SILICIO  Cerámicos             8.00
# 3        Acetato Butirado de Celulosa  Cerámicos           164.00
# 4                           Bentonita  Cerámicos             3.12
#
#    Densidad [kg/m^3]  Modulo de Young [GPa]  Esfuerzo de Fluencia [MPa]  \
# 0               10.0                  0.001                      0.0003
# 1               96.0                205.000                    400.0000
# 2              180.0                 66.300                         NaN
# 3              800.0                 50.000                         NaN
# 4             1360.0                  2.000                      1.5600
#
#    Esfuerzo Último [MPa]  Elongación [%]  Dureza [Vickers]  \
# 0                  0.016          0.0002               1.0
# 1               1400.000             NaN             100.0
# 2                300.000             NaN            3500.0
# 3                300.000             NaN             340.0
# 4                 55.000         20.0000             250.0
#
#    Tenacidad a la fractura [MPa m^1/2]  Temperatura de fusión [K]
# 0                                 4.80                     773.00
# 1                                 5.60                    2281.15
# 2                                 0.67                    1988.15
# 3                                 2.50                        NaN
# 4                                 3.40                    1473.15

# %%
print("La base de datos cuenta con {}  materiales".format(df.shape[0]))
# Out:
# La base de datos cuenta con 391  materiales

# %%
## Extraer nombres de las columnas
columns = df.columns.values.tolist()
columns
# Out:
# ['Nombre',
#  'Familia',
#  'Precio [USD/kg]',
#  'Densidad [kg/m^3]',
#  'Modulo de Young [GPa]',
#  'Esfuerzo de Fluencia [MPa]',
#  'Esfuerzo Último [MPa]',
#  'Elongación [%]',
#  'Dureza [Vickers]',
#  'Tenacidad a la fractura [MPa m^1/2]',
#  'Temperatura de fusión [K]']

# %% [markdown]
# ### Gráficar distribución datos material

# %%
# %matplotlib inline
columns_array = np.array(columns[1:]) # Convertir la lista de columnas a un arreglo sin el nombre de los materiales
columns_reshape = columns_array.reshape(5,2) # Redimensinando el arreglo  

fig, ax = plt.subplots(5, 2, figsize=(16,20)) # Se crea la malla subplot
fig.subplots_adjust(hspace=0.5, wspace=0.3) #  Espacio entre las gráficas

# Ciclo para gráficar los datos
for i in range(5):
    for j in range(2):
        ax[i][j].hist(df[columns_reshape[i][j]])
        ax[i][j].set(xlabel=columns_reshape[i][j])

# %% [markdown]
# ### Selección de pareja de Propiedades

# %%
# Creación de un arreglo para numerar las propiedades

propiedades = columns[2:]
numero = np.linspace(1,len(propiedades),len(propiedades)).astype(int).tolist()

mat = np.array(list(zip(numero,propiedades)))

# %%
print(mat)
print(" ")

N1 = int(input("Ingrese el número de la primera propiedad [1-9] (Eje Y): "))
P1 = propiedades[N1-1]

N2 = int(input("Ingrese el número de la segunda propiedad [1-9] (Eje X): "))
P2 = propiedades[N2-1]
print(" ")
print("Usted ha seleccionado {} (Eje Y) y {} (Eje X)".format(P1,P2))
# Out:
# [['1' 'Precio [USD/kg]']
#  ['2' 'Densidad [kg/m^3]']
#  ['3' 'Modulo de Young [GPa]']
#  ['4' 'Esfuerzo de Fluencia [MPa]']
#  ['5' 'Esfuerzo Último [MPa]']
#  ['6' 'Elongación [%]']
#  ['7' 'Dureza [Vickers]']
#  ['8' 'Tenacidad a la fractura [MPa m^1/2]']
#  ['9' 'Temperatura de fusión [K]']]
#
#
# Usted ha seleccionado Modulo de Young [GPa] (Eje Y) y Densidad [kg/m^3] (Eje X)

# %%
# Siglas de las propieades de la base de datos
siglas = symbols(["C","rho","E","sigma_y","sigma_U","L","H","K_{IC}","T_F"])
siglas
# Out:
# [C, ρ, E, σ_y, σ_U, L, H, K_{IC}, T_F]

# %%
# Definición de las siglas de las propiedades ingresadas por el usuario
s1 = siglas[N1-1]
s2 = siglas[N2-1]
s1,s2
# Out:
# (E, ρ)

# %% [markdown]
# ### Definición Índice de Materiales

# %%
# Exponente Propiedad 1
fr1 = input("El exponente de {} es fracción [Y/N]: ".format(P1))
if fr1 == "Y":
    num1, den1 = input("Ingrese el exponente de {}: ".format(P1)).split("/")
    exp1 = int(num1)/int(den1)
else:
    exp1 = int(input("Ingrese el exponente de {}: ".format(P1)))
    
# Exponente Propiedad 2
fr2 = input("El exponente de {} es fracción [Y/N]: ".format(P2))
if fr2 == "Y":
    num2, den2 = input("Ingrese el exponente de {}: ".format(P2)).split("/")
    exp2 = int(num2)/int(den2)
else:
    exp2 = int(input("Ingrese el exponente de {}: ".format(P2)))

# %%
print("El índice es:")
indice = (s1**(exp1))*(s2**(exp2))
indice
# Out:
# El índice es:
# E
# ─
# ρ

# %% [markdown]
# ### Definción orientación de búsqueda

# %%
if exp1 > 0 and exp2 > 0:
    ori = "max-max"
elif exp1 > 0 and exp2 <0:
    ori = "max-min"
elif exp1 < 0 and exp2 > 0:
    ori = "min-max"
else:
    ori = "min-min"
ori
# Out:
# 'max-min'

# %% [markdown]
# ### Ajuste de base de datos con base en los índices

# %%
df["Indice"] = (df[P1]**exp1)*(df[P2]**exp2)
df.head()
# Out:
#                                Nombre    Familia  Precio [USD/kg]  \
# 0                             Aerogel  Cerámicos           120.00
# 1  Manta Aislamiento Zirconia-alumina  Cerámicos           130.00
# 2                    OXIDO DE SILICIO  Cerámicos             8.00
# 3        Acetato Butirado de Celulosa  Cerámicos           164.00
# 4                           Bentonita  Cerámicos             3.12
#
#    Densidad [kg/m^3]  Modulo de Young [GPa]  Esfuerzo de Fluencia [MPa]  \
# 0               10.0                  0.001                      0.0003
# 1               96.0                205.000                    400.0000
# 2              180.0                 66.300                         NaN
# 3              800.0                 50.000                         NaN
# 4             1360.0                  2.000                      1.5600
#
#    Esfuerzo Último [MPa]  Elongación [%]  Dureza [Vickers]  \
# 0                  0.016          0.0002               1.0
# 1               1400.000             NaN             100.0
# 2                300.000             NaN            3500.0
# 3                300.000             NaN             340.0
# 4                 55.000         20.0000             250.0
#
#    Tenacidad a la fractura [MPa m^1/2]  Temperatura de fusión [K]    Indice
# 0                                 4.80                     773.00  0.000100
# 1                                 5.60                    2281.15  2.135417
# 2                                 0.67                    1988.15  0.368333
# 3                                 2.50                        NaN  0.062500
# 4                                 3.40                    1473.15  0.001471

# %%
# Valores Máximos y Mínimos de la Propiedad 1
max1 = df[P1].max()
min1 = df[P1].min()

s1,min1,max1
# Out:
# (E, 0.001, 670.0)

# %%
# Valores Máximos y Mínimos de la Propiedad 2
max2 = df[P2].max()
min2 = df[P2].min()

s2,min2,max2
# Out:
# (ρ, 1.1, 21500.0)

# %%
# Reordernar dataframe con base en los índices
df_ind = df.sort_values(by='Indice', ascending=False)
df_ind.head()
# Out:
#                                  Nombre     Familia  Precio [USD/kg]  \
# 1    Manta Aislamiento Zirconia-alumina   Cerámicos            130.0
# 148                               KCR10  Compuestos             20.0
# 147                              CTU08L  Compuestos             89.0
# 122             S3X7(Carburo cementado)  Compuestos             45.0
# 118                                S26T  Compuestos             75.0
#
#      Densidad [kg/m^3]  Modulo de Young [GPa]  Esfuerzo de Fluencia [MPa]  \
# 1                 96.0                  205.0                       400.0
# 148             1515.0                  660.0                         NaN
# 147             1505.0                  646.0                         NaN
# 122             1245.0                  530.0                         NaN
# 118             1220.0                  505.0                         NaN
#
#      Esfuerzo Último [MPa]  Elongación [%]  Dureza [Vickers]  \
# 1                   1400.0             NaN             100.0
# 148                 2800.0             NaN            1780.0
# 147                 3000.0             NaN            2300.0
# 122                 2150.0             NaN            1560.0
# 118                 1500.0             NaN            1570.0
#
#      Tenacidad a la fractura [MPa m^1/2]  Temperatura de fusión [K]    Indice
# 1                                    5.6                    2281.15  2.135417
# 148                                 10.1                        NaN  0.435644
# 147                                  8.4                        NaN  0.429236
# 122                                 10.7                        NaN  0.425703
# 118                                 10.8                        NaN  0.413934

# %%
# Cantidad de Materiales a Filtrar
mat = int(input("Ingrese el número de Materiales a Filtrar: "))

# %%
# Dataframe filtrado de acuerdo con el número de materiales
df_filt = df_ind.head(mat)
df_filt
# Out:
#                                                 Nombre     Familia  \
# 1                   Manta Aislamiento Zirconia-alumina   Cerámicos
# 148                                              KCR10  Compuestos
# 147                                             CTU08L  Compuestos
# 122                            S3X7(Carburo cementado)  Compuestos
# 118                                               S26T  Compuestos
# 119                                               S267  Compuestos
# 145                                             CTM14E  Compuestos
# 141                                              KCR32  Compuestos
# 149                            GC32 (cemented carbide)  Compuestos
# 135                                             CTS30D  Compuestos
# 2                                     OXIDO DE SILICIO   Cerámicos
# 131                                             CTF40A  Compuestos
# 201                                 \tTungsten Carbide     Metales
# 205                                        \tTungsteno     Metales
# 25                                    BORURO DE CALCIO   Cerámicos
# 208                                            Boro. B     Metales
# 27                                       Óxido de boro   Cerámicos
# 30                                     Carburo de boro   Cerámicos
# 169                                     Tyranno Fiber   Compuestos
# 163                                      E20 Beryllium  Compuestos
# 38                                            Cuarcita   Cerámicos
# 153                      Fibra de carbono (Vinilister)  Compuestos
# 51                                  Carburo de silicio   Cerámicos
# 158                                  PX 35 Carbon felt  Compuestos
# 46                             Oxido de beriliro (BeO)   Cerámicos
# 40                                  CARBURO DE VANADIO   Cerámicos
# 23           Piropilita tratada termicamente a 1250 °C   Cerámicos
# 151                                               GRFP  Compuestos
# 157                                               CFRP  Compuestos
# 161  Lámina plana de viniléster reforzado con vidri...  Compuestos
# 70                                 Diboruro de titanio   Cerámicos
# 45                      Oxido de Berilio Thermalox 995   Cerámicos
# 100      Cymat A35620SC 020SS Stabilized Aluminum Foam  Compuestos
# 160                                        Epoxy NP592  Compuestos
# 167                                       MMC: Mg-B(f)  Compuestos
# 66                               Zafiro Mateck (AL2o3)   Cerámicos
# 79                 Recubrimiento de nitruro de titanio   Cerámicos
# 175                        Carburo de silicio ceramico  Compuestos
# 302                                  Poliestireno (PS)   Polimeros
# 55                                 Nitruro de aluminio   Cerámicos
# 143                                             Kevlar  Compuestos
# 164                                     AlBeMet® AM162  Compuestos
# 64                         Oxido de aluminio DUROX UHP   Cerámicos
# 63                         Alumina. alpha Al2O3. 99.5%   Cerámicos
# 65                           Oxido de Aluminio Alúmina   Cerámicos
# 76                                  CARBURO DE TITANIO   Cerámicos
# 176       Electroconductive Alumina Composite (KA-EDM)  Compuestos
# 54                                              SIALON   Cerámicos
# 53                                  Nitruro de silicio   Cerámicos
# 226                              Titanium Carbide. TiC     Metales
#
#      Precio [USD/kg]  Densidad [kg/m^3]  Modulo de Young [GPa]  \
# 1            130.000               96.0                  205.0
# 148           20.000             1515.0                  660.0
# 147           89.000             1505.0                  646.0
# 122           45.000             1245.0                  530.0
# 118           75.000             1220.0                  505.0
# 119           46.000             1220.0                  505.0
# 145           16.000             1490.0                  615.0
# 141           26.000             1450.0                  580.0
# 149          100.000             1540.0                  580.0
# 135          100.000             1384.0                  512.0
# 2              8.000              180.0                   66.3
# 131           18.000             1360.0                  490.0
# 201           38.290             1480.0                  420.0
# 205           21.000             1930.0                  400.0
# 25           150.000             2430.0                  451.0
# 208          850.000             2599.0                  440.0
# 27             6.000             2460.0                  410.0
# 30            25.000             2500.0                  400.0
# 169           30.000             2480.0                  390.0
# 163            8.000             2050.0                  289.0
# 38           250.000             2699.0                  379.0
# 153           42.000             1650.0                  225.0
# 51           680.000             3100.0                  420.0
# 158           15.000             1810.0                  242.0
# 46            40.000             2900.0                  370.0
# 40           105.000             2710.0                  344.0
# 23          1038.000             2400.0                  300.0
# 151            8.800             1600.0                  200.0
# 157            7.300             1800.0                  225.0
# 161            0.180             1938.0                  241.0
# 70            79.000             4460.0                  540.0
# 45            25.680             2850.0                  345.0
# 100           13.700              200.1                   24.0
# 160           12.000             1900.0                  225.0
# 167          135.000             2450.0                  286.0
# 66           400.000             3980.0                  462.6
# 79             8.500             5200.0                  600.0
# 175           26.500             2900.0                  320.0
# 302            0.800               30.0                    3.2
# 55          1148.000             3330.0                  348.0
# 143           60.000             1470.0                  149.0
# 164           18.000             2070.0                  197.0
# 64            10.400             3950.0                  375.0
# 63           172.000             3900.0                  370.0
# 65           315.000             3960.0                  370.0
# 76           516.000             4940.0                  459.0
# 176            0.875             4200.0                  390.0
# 54            60.000             3250.0                  300.0
# 53           150.000             3250.0                  300.0
# 226           60.000             4940.0                  451.0
#
#      Esfuerzo de Fluencia [MPa]  Esfuerzo Último [MPa]  Elongación [%]  \
# 1                        400.00                 1400.0             NaN
# 148                         NaN                 2800.0             NaN
# 147                         NaN                 3000.0             NaN
# 122                         NaN                 2150.0             NaN
# 118                         NaN                 1500.0             NaN
# 119                         NaN                 1750.0             NaN
# 145                         NaN                  100.0             NaN
# 141                         NaN                  321.0             NaN
# 149                     2600.00                 4000.0             NaN
# 135                         NaN                 4300.0             NaN
# 2                           NaN                  300.0             NaN
# 131                         NaN                  321.0             NaN
# 201                      167.00                   64.0        71.00000
# 205                      156.00                   47.0        53.00000
# 25                          NaN                  600.0             NaN
# 208                      127.00                  244.0        11.00000
# 27                          NaN                  350.0             NaN
# 30                          NaN                  410.0         0.00124
# 169                      300.00                  550.0         1.70000
# 163                      158.00                  207.0         4.00000
# 38                       170.00                  330.0             NaN
# 153                         NaN                  136.0         1.60000
# 51                          NaN                 4600.0             NaN
# 158                         NaN                 4137.0         1.40000
# 46                          NaN                  140.0         0.00082
# 40                          NaN                  350.0             NaN
# 23                        34.40                  151.6             NaN
# 151                     1250.00                 1465.0         3.32000
# 157                     1300.00                 1600.0         2.15000
# 161                       33.76                   51.7        15.20000
# 70                          NaN                  350.0         0.00089
# 45                       150.00                  152.0             NaN
# 100                       53.00                   70.0         9.20000
# 160                         NaN                  241.0             NaN
# 167                      880.00                 1055.0         0.45000
# 66                          NaN                  162.9             NaN
# 79                          NaN                  400.0             NaN
# 175                         NaN                  400.0             NaN
# 302                       30.00                   50.0         2.50000
# 55                          NaN                  270.0             NaN
# 143                     2900.00                 3450.0         3.00000
# 164                      193.00                  262.0         2.00000
# 64                       270.00                  276.0             NaN
# 63                       350.00                  260.0             NaN
# 65                          NaN                  300.0             NaN
# 76                        59.00                  258.0             NaN
# 176                         NaN                 1200.0             NaN
# 54                          NaN                   40.0             NaN
# 53                          NaN                  537.0         0.00169
# 226                      193.00                  254.0        43.00000
#
#      Dureza [Vickers]  Tenacidad a la fractura [MPa m^1/2]  \
# 1              100.00                                 5.60
# 148           1780.00                                10.10
# 147           2300.00                                 8.40
# 122           1560.00                                10.70
# 118           1570.00                                10.80
# 119           1570.00                                10.80
# 145           1550.00                                10.40
# 141           1140.00                                16.50
# 149           1130.00                                18.00
# 135           1425.00                                12.20
# 2             3500.00                                 0.67
# 131           1070.00                                18.00
# 201            287.00                                27.00
# 205            310.00                                30.00
# 25            1110.00                                 2.80
# 208            260.00                                 3.20
# 27            1000.00                                 3.20
# 30            3200.00                                 4.20
# 169             15.20                                 3.80
# 163            500.00                                25.00
# 38            2070.00                                 3.70
# 153             88.45                                11.20
# 51            2500.00                                 5.43
# 158            700.00                                10.00
# 46            1200.00                                 1.30
# 40            2950.00                                 7.30
# 23             858.00                                 3.90
# 151             56.00                                 8.90
# 157             60.00                                12.00
# 161             71.00                                 3.40
# 70            3060.00                                 5.50
# 45             106.30                                 3.50
# 100             12.00                                 1.94
# 160            316.00                                 3.60
# 167            145.00                                 5.50
# 66            2200.00                                 7.70
# 79            1969.00                                 2.30
# 175           2005.00                                 4.60
# 302             75.00                                 0.40
# 55            1800.00                                 2.75
# 143             30.00                                 4.00
# 164            123.00                                32.00
# 64             169.77                                 5.00
# 63            2000.00                                 4.00
# 65            1365.00                                 4.00
# 76            3200.00                                 6.72
# 176           2294.00                                 8.00
# 54            1500.00                                 7.00
# 53            1600.00                                 7.50
# 226             95.00                               160.00
#
#      Temperatura de fusión [K]    Indice
# 1                      2281.15  2.135417
# 148                        NaN  0.435644
# 147                        NaN  0.429236
# 122                        NaN  0.425703
# 118                        NaN  0.413934
# 119                        NaN  0.413934
# 145                        NaN  0.412752
# 141                        NaN  0.400000
# 149                    1000.00  0.376623
# 135                        NaN  0.369942
# 2                      1988.15  0.368333
# 131                        NaN  0.360294
# 201                    3058.15  0.283784
# 205                    3610.15  0.207254
# 25                     2508.15  0.185597
# 208                    2573.00  0.169296
# 27                      753.00  0.166667
# 30                     2680.00  0.160000
# 169                    1723.15  0.157258
# 163                        NaN  0.140976
# 38                         NaN  0.140422
# 153                    3970.00  0.136364
# 51                     2800.00  0.135484
# 158                        NaN  0.133702
# 46                     2800.00  0.127586
# 40                     3003.15  0.126937
# 23                     1873.15  0.125000
# 151                        NaN  0.125000
# 157                        NaN  0.125000
# 161                     293.00  0.124355
# 70                     3500.00  0.121076
# 45                     2848.15  0.121053
# 100                     573.00  0.119940
# 160                     404.15  0.118421
# 167                     921.00  0.116735
# 66                     2303.00  0.116231
# 79                     3223.15  0.115385
# 175                    2720.00  0.110345
# 302                     543.15  0.106667
# 55                     2780.00  0.104505
# 143                     803.15  0.101361
# 164                    1355.15  0.095169
# 64                     2323.15  0.094937
# 63                     2700.00  0.094872
# 65                     2054.00  0.093434
# 76                     3338.15  0.092915
# 176                        NaN  0.092857
# 54                     1700.00  0.092308
# 53                     2173.00  0.092308
# 226                    3338.15  0.091296

# %% [markdown]
# ### Cálculo línea de filtrado

# %%
# Se calcula la constante de proporción c = P1^(exp1)*P2^(exp2)
c = (df_filt[P1].iloc[-1])**(exp1)*(df_filt[P2].iloc[-1])**(exp2) 

# Se calculan los valores máximos y mínimos de la línea 
ymin = (c/(min2**(exp2)))**(1/exp1)
ymax = (c/(max2**(exp2)))**(1/exp1)

# %% [markdown]
# ### Gráfica pareja propiedades

# %%
# La gráfica no queda Inline para poder hacer zoom 
# %matplotlib inline

f, ax = plt.subplots(figsize=(16, 9)) #Se define el tamaño de la gráfica

ax.set(xscale="log", yscale="log", xlim = (min2, max2), ylim = (min1, max1)) # Se establece el tipo de escala y limites 

sns.scatterplot(x=P2, y=P1, data=df, hue="Familia", s = 100, alpha = 0.5) # Se gráfican los punto de materiales

ax.plot([min2,max2],[ymin,ymax],"r") # Se gráfica la línea de filtrado

# Sombreado de selección hacia arriba
if ori == "max-min" or ori == "max-max":
    # x valores de x, y1 valores de la linea, y2 dirección de sombreado, color hexadecial, zorder = 0 evita borrar puntos sns
    ax.fill_between(x = [min2, max2], y1 = [ymin, ymax], y2=[max1,max1], color="#d7e8d5", zorder = 0) # verde selección
    ax.fill_between(x = [min2, max2], y1 = [ymin, ymax], y2=[min1,min1], color="#fae4e4", zorder = 0) # rojo no selección

# Sombreado de selección hacia abajo
elif ori == "min-max" or ori == "min-min":
    # x valores de x, y1 valores de la linea, y2 dirección de sombreado, color hexadecial, zorder = 0 evita borrar puntos sns
    ax.fill_between(x = [min2, max2], y1 = [ymin, ymax], y2=[max1,max1], color="#fae4e4", zorder = 0) # rojo no selección
    ax.fill_between(x = [min2, max2], y1 = [ymin, ymax], y2=[min1,min1], color="#d7e8d5", zorder = 0) # verde selección
    
ax.grid() # Malla
